# %% [markdown]
# # Notebook Summary
#
# This web scraper takes in a list of Medium user profiles and collectsa list of articles written by each user. It then scrapes each of those articles for a set of traits, ranging from article length to a readibility score. These traits are used for analysis in Step 3 of this project.

# %% [markdown]
# # Inital Imports

# %%
import json
import requests
from lxml import html
from bs4 import BeautifulSoup
from collections import OrderedDict
import argparse
import re
import dateutil.parser
import pandas as pd
import time
from selenium import webdriver
from textatistic import Textatistic
import pickle
import numpy as np
from selenium.common.exceptions import TimeoutException
from textblob import TextBlob
import random
import os

# %% [markdown]
# # Get urls for articles from inital scrape

# %%
#bring in the 'iterator' list from medium-graph-scrape, and dedupe it into a set
with open("pickles/jonathonmorgan_all_the_people.pkl", 'rb') as picklefile: 
    all_the_people = pickle.load(picklefile)
all_the_people = set(all_the_people)

# %%
#make a sample to work with
people = list(all_the_people)
sample= people[-10:]
sample
# Out:
# ['https://medium.com/@sabinakrupic',
#  'https://medium.com/@oh_steph',
#  'https://medium.com/@mawwwk',
#  'https://medium.com/@namitajamwal19',
#  'https://medium.com/@michaeltbaker22',
#  'https://medium.com/@mrdollywaggle',
#  'https://medium.com/@charlesliu2012',
#  'https://medium.com/@neutunlabs',
#  'https://medium.com/@msf_fr',
#  'https://medium.com/@rachele.gilman']

# %%
#Declare data structures
master_articles = []
master_people = {}

# %% [markdown]
# ## Create global functions

# %%
def get_home_articles(soup):
'''This function gets the articles from a given users home page'''
    article_urls = []
    try:
        articles = soup.find_all('a', {'data-action':'open-post'})
        for item in articles:
            if item.text == 'Read more…':
                url = (item['href'])
                url = re.sub('\?source(.*)','',url)
                article_urls.append(url)
        return article_urls
    except: []
# Out:
#   File "<ipython-input-11-41282f89d616>", line 2
#     '''This function gets the articles from a given users home page'''
#                                                                      ^
# IndentationError: expected an indented block

# %%
def count_followers(soup):
    '''count followers from the home page'''
    try: 
        followers = soup.find(attrs ={'data-action-value':'followers'})
        follower_count = followers.text
        return follower_count.replace(" Followers", "")
    except AttributeError:
        return 0

        
def count_leaders(soup):
    '''count leaders from the home page'''
    try: 
        following = soup.find(attrs ={'data-action-value':'following'})
        following_count= following.text
        return following_count.replace(" Following", "")
    except AttributeError:
        return 0

def get_name(soup):
    try: 
        name = soup.find('h1',{'class':'ui-h2 hero-title' })
        return name.text
    except AttributeError:
        return 0

# %% [markdown]
# ## Loop through people and get article urls

# %%
driver = webdriver.Chrome(executable_path="/Users/mayamidzik/tools/chromedriver")

for url in people:
    url_latest= url+'/latest'
    driver.get(url_latest)
    
    #scroll to bottom of page
    SCROLL_PAUSE_TIME = 0.1
    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    #get the html for the page
    innerHTML = driver.execute_script("return document.body.innerHTML")
    soup = BeautifulSoup(innerHTML,"lxml")
    
    
#     pickle_name = re.search('@(.*)',url).group(0)
#     print(pickle_name)
#     with open('/Users/mayamidzik/backups/pickles/person_homes/'+ pickle_name+'_home.pkl', 'wb') as picklefile:
#         pickle.dump(soup, picklefile)
    
    followers_count = count_followers(soup)
    leaders_count = count_leaders(soup)
    name = get_name(soup)
    master_people[url]=({'followers':followers_count})
    master_people[url].update({'leaders':leaders_count})
    master_people[url].update({'name':name})
    
    
    articles = get_home_articles(soup)
    master_articles.extend(articles)

# %%
#save to pickle
with open('SenateGOP_master_articles.pkl', 'wb') as picklefile:
    pickle.dump(master_articles, picklefile)

# %%
len(master_people)
# Out:
# 2233

# %%
master_people_df = pd.DataFrame.from_dict(master_people).T

# %%
master_people_df.reset_index(level=0, inplace=True)
master_people_df.rename(columns = {'index':'url'},inplace = True)
master_people_df.head()
# Out:
#                                 url followers leaders             name
# 0    https://medium.com/@0504567335        26     536   AHMAD ALASHRAM
# 1  https://medium.com/@12Sherwoodcp         2      10       L Sherwood
# 2  https://medium.com/@1800Ethernet        24     547  Ethernet.GLOBAL
# 3   https://medium.com/@1LuisFarias        14      87      Luis Farias
# 4          https://medium.com/@1PNR        13     404  PIERRE N. ROLIN

# %%
with open('SenateGOP_people.pkl', 'wb') as picklefile:
    pickle.dump(master_people, picklefile)

# %% [markdown]
# # Get article traits from urls

# %% [markdown]
# ## Define functions for attributes

# %%
with open("pickles/jonathonmorgan_master_articles.pkl", 'rb') as picklefile: 
    master_articles = pickle.load(picklefile)

# %%
master_articles
# Out:
# ['https://blog.medium.com/let-s-take-it-to-medium-6f3607a77f70',
#  'https://blog.medium.com/good-embed-eacdce5f2933',
#  'https://blog.medium.com/taking-a-side-on-net-neutrality-11bca5a2f118',
#  'https://blog.medium.com/blocking-and-tracking-3b74da2fd881',
#  'https://medium.com/@feerst/on-the-death-of-a-very-good-lawyer-i-never-met-a1cc1d43d446',
#  'https://medium.com/@biggreenbox/our-5-step-methodology-for-predictive-analytics-79fa22c5f3be',
#  'https://medium.com/@danielresende/como-fazer-um-computador-ver-356849d3c86b',
#  'https://medium.com/@mlbayless92/what-i-have-read-and-what-i-am-currently-reading-dff6b8a8db55',
#  'https://medium.com/@mlbayless92/challenging-your-opinions-c2bc011dcbdc',
#  'https://medium.com/@mlbayless92/the-very-short-history-of-fbi-directors-1f4e550cecf5',
#  'https://blog.politicsmeanspolitics.com/about-time-a8f07b276c38',
#  'https://medium.com/@mlbayless92/the-biggest-loser-usaid-eeb2fd867c3',
#  'https://medium.com/@biggreenbox/our-5-step-methodology-for-predictive-analytics-79fa22c5f3be',
#  'https://medium.com/@danielresende/como-fazer-um-computador-ver-356849d3c86b',
#  'https://medium.com/@mlbayless92/what-i-have-read-and-what-i-am-currently-reading-dff6b8a8db55',
#  'https://medium.com/@mlbayless92/challenging-your-opinions-c2bc011dcbdc',
#  'https://medium.com/@mlbayless92/the-very-short-history-of-fbi-directors-1f4e550cecf5',
#  'https://blog.politicsmeanspolitics.com/about-time-a8f07b276c38',
#  'https://medium.com/@mlbayless92/the-biggest-loser-usaid-eeb2fd867c3',
#  'https://medium.com/@melissaryan/what-is-weaponization-836dc8b006b9',
#  'https://medium.com/@melissaryan/57-billion-friendships-8536fc76c14e',
#  'https://medium.com/@melissaryan/frogs-and-elephants-1e078ed32fc9',
#  'https://medium.com/@melissaryan/game-recognize-game-1cbeebcb7827',
#  'https://medium.com/@melissaryan/for-zucks-sake-8d055529bdd3',
#  'https://medium.com/@astrobiased/exploratory-data-analysis-and-graphics-9943dc2fb26',
#  'https://medium.com/quicksand/better-decisions-through-better-interactions-72207e6f4b4a',
#  'https://medium.com/quicksand/towards-a-more-open-nz-e045bbf14196',
#  'https://zetetic.nz/let-your-shoes-do-the-talking-online-play-in-professional-social-networks-29c0172596',
#  'https://medium.com/quicksand/voting-then-and-now-1893-and-2017-61809d56135b',
#  'https://zetetic.nz/raising-ais-a3d4f5ec03d4',
#  'https://medium.com/quicksand/open-data-and-us-197235560226',
#  'https://medium.com/quicksand/international-open-data-day-wellington-5eb9358b9842',
#  'https://medium.com/quicksand/service-design-for-councils-better-gisborne-events-cbbca1cc8d52',
#  'https://medium.com/quicksand/open-data-and-apis-fuelling-innovation-52962468da7b',
#  'https://medium.com/quicksand/flaxroots-civic-tech-in-new-zealand-72d26cc9cdc6',
#  'https://medium.com/devopslinks/backing-up-banking-fsi-cloud-native-apps-on-aws-87c19b510220',
#  'https://medium.com/devopslinks/requirements-of-compliant-data-backup-for-cloud-native-applications-on-aws-52e98636612e',
#  'https://medium.com/@arseny.chernov/nomad-vs-yarn-vs-kubernetes-vs-borg-vs-mesos-vs-you-name-it-7f15a907ece2',
#  'https://medium.com/devopslinks/nfs-benchmarking-on-amazon-aws-43e0fb9d4b90',
#  'https://medium.com/@arseny.chernov/how-to-cook-broccoli-to-preserve-maximum-antioxidants-fedf19c607fb',
#  'https://medium.com/@arseny.chernov/migrate-api-from-aws-s3-to-aliyun-oss-640dd1e74201',
#  'https://medium.com/@arseny.chernov/securing-devops-review-of-approaches-a801742630ca',
#  'https://medium.com/@arseny.chernov/stress-meaningful-work-dream-job-and-quadriceps-between-the-ears-395a1aec46c4',
#  'https://medium.com/@arseny.chernov/random-air-refuelling-a-helicopter-d3d22191bd7d',
#  'https://medium.com/@arseny.chernov/rescue-time-and-coalesce-interrupts-c9a3f23cbd39',
#  'https://medium.com/@katherinebailey/can-machine-learning-answer-your-question-709ddcebe92c',
#  'https://medium.com/@katherinebailey/theres-something-fishy-about-the-idea-of-artificial-human-intelligence-ahi-cc23de623185',
#  'https://medium.com/@katherinebailey/hashtag-artificial-intelligence-47ff35e6a9cc',
#  'https://medium.com/@katherinebailey/reframing-the-ai-effect-c445f87ea98b',
#  'https://medium.com/@katherinebailey/why-machine-learning-is-not-a-path-to-the-singularity-540d957ef847',
#  'https://medium.com/@StatisticSingh/conservative-party-conference-2017-predictions-e5fa569f0618',
#  'https://medium.com/@StatisticSingh/while-angry-leave-voters-believe-that-democracy-is-being-subverted-by-enemies-of-the-people-b8d5dc140327',
#  'https://medium.com/@peteskomoroch/oreilly-bots-podcast-interview-on-the-future-of-bots-d03edceb56ba',
#  'https://medium.com/@peteskomoroch/stone-soup-en-wikipedia-org-176cd68980fd',
#  'https://medium.com/cinematicvr/my-virtual-reality-mea-culpa-945dea7464c',
#  'https://medium.com/@valfarly/virtual-reality-success-virtually-impossible-to-predict-f941685f7d4',
#  'https://medium.com/@valfarly/ces-consumer-electronics-show-or-crazy-ephemeral-shenanigans-abf4879ff202',
#  'https://medium.com/k%C3%BChner-kommentar/u-s-flag-etiquette-american-first-except-during-church-services-at-sea-f54fe4c75e1f',
#  'https://medium.com/k%C3%BChner-kommentar/a-brief-history-of-the-christian-conquest-flag-movement-in-the-usa-1901-42-76409e9f0944',
#  'https://medium.com/@danmckernan/5-ways-to-disconnect-on-your-lunch-break-f53853fa1a42',
#  'https://medium.com/@cgtheoret/what-i-learned-at-the-first-founder-x-summit-c0f4cb7ddd9e',
#  'https://insights.nexalogy.com/ostracism-is-community-2ee6cf7a44f',
#  'https://insights.nexalogy.com/announcing-nx-api-4d4b970427a7',
#  'https://insights.nexalogy.com/ostracism-is-community-efe68fa8e44c',
#  'https://insights.nexalogy.com/when-tech-intelligence-exceeds-collective-wisdom-5a1c093e2f3b',
#  'https://insights.nexalogy.com/coworkings-essential-space-in-the-startup-ecology-ab4a552839ea',
#  'https://insights.nexalogy.com/nexalogy-headed-to-silicon-valley-in-2012-thanks-to-cix-d23a77bd41b2',
#  'https://insights.nexalogy.com/the-oncoming-social-data-analysis-revolution-e60947a1ec5f',
#  'https://insights.nexalogy.com/the-consequences-of-social-media-influence-measurement-72509a6d14e2',
#  'https://insights.nexalogy.com/startup-festival-and-the-best-of-the-valley-2b4e91611bdd',
#  'https://medium.com/nativedata/meet-nick-lockwood-vp-client-services-b0aade375cd3',
#  'https://medium.com/@huslage/american-kids-6934b953a4a7',
#  'https://medium.com/@s4n1ty/trump-is-playing-the-wrong-game-4d3ffeb85790',
#  'https://medium.com/@s4n1ty/introducing-kweb-a-unique-new-approach-to-building-rich-web-applications-940133247389',
#  'https://medium.com/@s4n1ty/experimenting-with-mutation-testing-and-kotlin-b515d77e85b5',
#  'https://medium.com/@s4n1ty/star-ratings-are-dangerous-5be29d51a88b',
#  'https://medium.com/@s4n1ty/the-game-theory-of-sealed-bid-auctions-41d272397781',
#  'https://medium.com/@s4n1ty/predicting-the-future-10-000-times-per-second-f3b477dc00a',
#  'https://medium.com/@s4n1ty/arguments-you-can-make-as-a-startup-cto-against-software-patents-4bb719a4c3d7',
#  'https://medium.com/@s4n1ty/the-purpose-of-software-project-management-92d621d3dea3',
#  'https://medium.com/@s4n1ty/lastcalc-google-calculator-meets-haskell-meets-prolog-ebcf7f7b2306',
#  'https://machinelearnings.co/machine-learnings-google-to-help-dod-analyze-drone-footage-833914a91c2e',
#  'https://machinelearnings.co/machine-learnings-creepy-ai-surveillance-strokes-and-gun-control-ff7aab7d8d6b',
#  'https://machinelearnings.co/how-to-develop-an-ai-product-d3c4814e0908',
#  'https://machinelearnings.co/youtubes-algorithm-is-back-in-the-news-for-all-the-wrong-reasons-c468b2544bc3',
#  'https://machinelearnings.co/machines-for-creative-enablement-c2d2c40c1ad0',
#  'https://machinelearnings.co/machine-learnings-facebooks-big-algorithm-change-2f85c698f79a',
#  'https://machinelearnings.co/machine-learning-wont-reach-its-potential-without-the-human-element-5b030051cd9d',
#  'https://blog.usejournal.com/get-off-social-media-by-shifting-your-attention-to-a-demanding-app-7e2dc2409bd0',
#  'https://blog.usejournal.com/the-biggest-source-of-interruption-at-work-isnt-external-7cc3b6ff6fc3',
#  'https://blog.usejournal.com/give-your-brain-a-break-d81efb4d27f1',
#  'https://trivial.io/stream-processing-in-pysparkling-772d6de777ee',
#  'https://trivial.io/databench-v0-4-fc2f69131db4',
#  'https://trivial.io/word2vec-on-databricks-791157831eaa',
#  'https://trivial.io/parallel-processing-with-pysparkling-51056ac9875a',
#  'https://trivial.io/pysparkling-talks-147fbf878642',
#  'https://trivial.io/pysparkling-2114da91de0c',
#  'https://trivial.io/wildcardians-on-twitter-9d0237b2207e',
#  'https://trivial.io/collaborative-statistical-modeling-21bfad74de86',
#  'https://medium.com/sidewalk-talk/s2-cells-and-space-filling-curves-keys-to-building-better-digital-map-tools-for-cities-a312aa5e2f59',
#  'https://towardsdatascience.com/so-how-many-ml-models-you-have-not-built-e692f549b163',
#  'https://towardsdatascience.com/hawaii-false-missile-alert-removing-confusion-from-confusion-matrix-75b53f8caab9',
#  'https://towardsdatascience.com/which-machine-learning-algo-will-continue-to-be-in-use-in-year-2118-59d0461160f3',
#  'https://towardsdatascience.com/want-to-become-a-data-scientist-try-feynman-technique-2ea010da1c54',
#  'https://towardsdatascience.com/how-to-dockerize-an-r-shiny-app-part-1-d4267659312a',
#  'https://towardsdatascience.com/recommender-engine-under-the-hood-7869d5eab072',
#  'https://towardsdatascience.com/how-to-host-a-r-shiny-app-on-aws-cloud-in-7-simple-steps-5595e7885722',
#  'https://medium.com/@ijanric/creating-a-data-culture-fbc20877348e',
#  'https://medium.com/@BlairReeves/the-new-monopolists-59ede5823b6',
#  'https://medium.com/@BlairReeves/one-way-big-tech-can-help-bring-america-together-hire-people-where-they-are-d4d16bf2f50f',
#  'https://medium.com/@BlairReeves/how-should-product-managers-spend-their-time-41f221f2978f',
#  'https://medium.com/@BlairReeves/star-trek-frontier-1468a6fb9103',
#  'https://medium.com/@BlairReeves/the-democratic-face-of-the-new-south-c1dac4cd5bf8',
#  'https://medium.com/@BlairReeves/platform-management-45b8d2838c18',
#  'https://medium.com/@BlairReeves/why-acquisitions-fail-or-succeed-ca40259ee927',
#  'https://medium.com/@BlairReeves/remote-working-is-the-future-and-it-should-be-the-present-667c3c96c9fe',
#  'https://digitalculturist.com/big-tech-is-headed-for-regulation-whether-it-likes-it-or-not-ef95b9947597',
#  'https://medium.com/@BlairReeves/learning-how-to-listen-657547afaf61',
#  'https://resistthegunlobby.org/when-we-founded-our-organization-we-said-that-if-lawmakers-didnt-find-the-courage-to-support-life-752b067d3be4',
#  'https://medium.com/democratic-national-convention/why-i-want-to-say-madam-president-come-january-66ca8593ec70',
#  'https://medium.com/@GabbyGiffords/no-bill-no-break-812a94ef60bb',
#  'https://medium.com/@GabbyGiffords/why-mark-i-are-supporting-hillary-clinton-for-president-34f8867be2c',
#  'https://medium.com/@GabbyGiffords/why-congress-needs-to-act-on-the-new-bipartisan-bill-to-keep-guns-out-of-the-hands-of-abusers-and-2c1cd2f51eb5',
#  'https://medium.com/@cathyhan/9-lessons-i-learned-from-y-combinator-55b0fe3c6bcb',
#  'https://medium.com/@bestimmigration/why-to-travel-on-ethiopian-airlines-5b7affe41e53',
#  'https://medium.com/fitchain/decentralized-machine-learning-b9fa9d78710',
#  'https://medium.com/@frag/this-is-how-ethereum-works-60f37abd5ef5',
#  'https://medium.com/@frag/when-will-banks-and-governments-feel-it-319eb0461ab4',
#  'https://medium.com/@frag/the-most-reliable-bulls-t-about-ai-killing-humans-15c3a34f9ae3',
#  'https://medium.com/@frag/lessons-learned-from-a-top-global-fintech-accelerator-part-2-be01237cb376',
#  'https://medium.com/@frag/lessons-learned-from-a-top-global-fintech-accelerator-part-1-b58b768a2e77',
#  'https://medium.com/@frag/how-to-master-optimisation-in-deep-learning-5c07cf3a7644',
#  'https://medium.com/@frag/completely-change-your-data-analytics-strategy-with-deep-learning-36fdff573f11',
#  'https://medium.com/data-science-at-home/corporate-industry-84456af827f9',
#  'https://medium.com/data-science-at-home/how-different-is-ethereum-from-bitcoin-33e1fb5690b3',
#  'https://medium.com/@philliproman/elena-of-avalor-is-latina-f8873ced321e',
#  'https://medium.com/@seanjtaylor/the-personality-space-of-cartoon-characters-e1d7b2009c15',
#  'https://medium.com/rasa-blog/a-new-approach-to-conversational-software-2e64a5d05f2a',
#  'https://medium.com/rasa-blog/do-it-yourself-nlp-for-bot-developers-2e2da2817f3d',
#  'https://medium.com/rasa-blog/we-don-t-know-how-to-build-conversational-software-yet-a18301db0e4b',
#  'https://medium.com/@alanmnichol/on-slack-and-brainwaves-6f268246fece',
#  'https://medium.com/@akalmans/ironcore-labs-securely-accelerating-the-shift-to-the-cloud-via-a-new-paradigm-251a5dc32390',
#  'https://austinstartups.com/nvidia-gtc-innovation-accelerating-ecosystem-gelling-opportunity-for-human-advancement-e712134f3331',
#  'https://austinstartups.com/bitfusion-flex-e1e992e8279f',
#  'https://austinstartups.com/apis-the-key-to-navigating-festivals-like-sxsw-f74fb60f1385',
#  'https://austinstartups.com/amazon-redshift-too-slow-or-crashing-blazingdb-performs-92019540a01f',
#  'https://austinstartups.com/atlas-shape-6c49d429c07e',
#  'https://austinstartups.com/anacondacon17-opendatasciencemeans-8fbe31ceeecf',
#  'https://austinstartups.com/appbase-delivers-on-global-users-expectation-for-realtime-apps-tapping-into-4-5-b-market-f5781e075f2c',
#  'https://medium.com/@akalmans/rackn-91-b-market-opportunity-2k17-year-of-massive-growth-1c88625588ad',
#  'https://medium.com/@akalmans/2k17-lets-make-it-real-ef6abc5869e1',
#  'https://medium.com/@aweiss/aarons-holiday-tech-guide-2014-edition-a2c7bc63d024',
#  'https://medium.com/@neutunlabs/4-best-practices-for-reducing-epileptic-seizures-d4ea0c2bef5f',
#  'https://blog.neutun.com/epilepsy-a-quick-primer-b30576a6b589',
#  'https://blog.neutun.com/how-seizure-sync-makes-epilepsy-suck-less-850f7629af7c',
#  'https://blog.neutun.com/epilepsy-and-the-keto-diet-f923e30223bc',
#  'https://blog.neutun.com/how-one-mother-is-beating-epilepsy-after-26-years-d907607d713a',
#  'https://medium.com/@neutunlabs/peace-of-mind-from-any-device-388b6b415296',
#  'https://blog.neutun.com/peace-of-mind-from-any-device-b24666d9dd10',
#  'https://medium.com/@ahmedmedien/melltoo-s-first-anniversary-a-year-of-many-achievements-c915d325ccdb',
#  'https://medium.com/@ahmedmedien/how-to-succeed-as-a-young-entrepreneur-in-the-middle-east-5cfc2ac847ec',
#  'https://medium.com/datasd/netlify-site-of-the-week-2e9f9580a8c3',
#  'https://medium.com/datasd/a-few-updates-to-streetssd-a6b3e5a50610',
#  'https://medium.com/datasd/city-streetlights-get-smart-670e6a30730e',
#  'https://medium.com/datasd/san-diegos-open-data-portal-video-86679e8d2698',
#  'https://medium.com/datasd/solar-permits-prediction-city-of-san-diego-open-data-portal-131e40c531db',
#  'https://medium.com/@mrmaksimize/chief-data-and-sustainability-officers-form-an-effective-team-adab9513889d',
#  'https://medium.com/@mrmaksimize/datasd-is-hiring-8875ba05ac54',
#  'https://medium.com/datasd/why-data-automation-matters-4391d59e1952',
#  'https://medium.com/datasd/a-faster-data-portal-f42957d34214',
#  'https://medium.com/@mrmaksimize/savvy-savannah-1e89c63f5600',
#  'https://medium.com/icopass/writing-an-ethereum-wallet-for-fun-e82a05322ae2',
#  'https://medium.com/icopass/the-token-economy-ec9ef2ab728',
#  'https://medium.com/@metamje/setting-up-remote-debugging-for-a-java-application-in-eclipse-with-heroku-exec-22d0722371c2',
#  'https://medium.com/@jazzmyth/1-2-3-merge-fe8f6b27f1e3',
#  'https://medium.com/@jazzmyth/making-facebook-events-safer-for-survivors-cfdc42dee9f8',
#  'https://medium.com/compassred-data-blog/leveraging-r-the-good-the-bad-and-the-better-way-ee86f5d7a6f6',
#  'https://medium.com/compassred-data-blog/5-core-takeaways-in-the-gardner-2017-state-of-business-intelligence-2017-334f07cfc90f',
#  'https://medium.com/compassred-data-blog/our-5-step-process-for-predictive-analytics-d9ee4bbc5d02',
#  'https://medium.com/@Twitt3rlessSeth/barely-hops-water-and-yeast-e16cbd2c8a50',
#  'https://medium.freecodecamp.org/how-to-read-your-way-to-becoming-a-better-developer-b6432fa5bc0c',
#  'https://medium.com/pintail-labs/what-is-the-smack-stack-31bc85131a9a',
#  'https://medium.com/pintail-labs/docker-series-moving-past-one-container-bf32b45831d3',
#  'https://medium.com/pintail-labs/docker-series-building-your-first-image-8a6f051ae637',
#  'https://medium.com/pintail-labs/docker-series-creating-your-first-dockerfile-573bfea4991',
#  'https://medium.com/pintail-labs/docker-series-starting-your-first-container-92dfd1dc859',
#  'https://medium.com/pintail-labs/docker-series-cheat-sheet-e1841961c61',
#  'https://medium.com/pintail-labs/docker-series-what-is-docker-9eddca88f434',
#  'https://medium.com/pintail-labs/a-great-debate-what-language-for-data-science-bdd265b33f38',
#  'https://medium.com/pintail-labs/oscon-2016-collaboration-creates-quality-1cec8dc1c625',
#  'https://medium.com/@andrewjamesinc/what-meditation-has-taught-me-about-f-ups-384c5f10d0b7',
#  'https://medium.com/@andrewjamesinc/when-making-data-driven-decisions-beware-2d60acb3d9e1',
#  'https://medium.com/@andrewjamesinc/high-to-high-or-low-to-low-6b0f9ba1c51e',
#  'https://medium.com/@andrewjamesinc/this-video-makes-me-want-to-spend-a-lot-more-on-my-next-tv-76ba79764ac9',
#  'https://medium.com/@andrewjamesinc/priorities-vs-importance-e195294a3866',
#  'https://medium.com/@andrewjamesinc/11-11-veterans-day-1eadeaa71b0b',
#  'https://medium.com/@andrewjamesinc/swipe-a-simple-3-paragraph-pre-sell-page-675d5735b84b',
#  'https://medium.com/@andrewjamesinc/3-meetings-with-people-ive-known-a-long-time-3fa1f6b851e8',
#  'https://medium.com/@andrewjamesinc/p-s-stands-for-place-to-sell-3e6f7201ccb2',
#  'https://medium.com/@Mahantesh19/thanks-dr-kannan-for-sharing-your-thoughts-about-researchstash-with-your-network-4df4831288a5',
#  'https://medium.com/@Mahantesh19/congratulations-you-are-digitally-distinct-d7d0c5194047',
#  'https://medium.com/@Mahantesh19/we-are-excited-to-launch-sciglo-student-ambassador-program-ssap-39fd907b2d4',
#  'https://medium.com/@Mahantesh19/elife-and-authorea-partner-to-simplify-submission-for-authors-8d2373e5a1',
#  'https://medium.com/@Mahantesh19/launching-science-trivia-by-tiffany-s-b040e8d38256',
#  'https://medium.com/@Mahantesh19/vivaldibrowser-thank-you-so-much-for-the-christmas-goodies-e76cdbe928fd',
#  'https://medium.com/@Mahantesh19/the-boiling-frog-theory-f20353dd739f',
#  'https://medium.com/@Mahantesh19/hurray-3ea5eeda28f9',
#  'https://medium.com/@Mindful.Writer/this-is-not-your-dream-2072d0610ac6',
#  'https://writing.rajanand.org/introduction-to-r-basics-761f94ea949f',
#  'https://medium.com/through-the-datascope/outside-a-train-rumbles-by-75ccf3cf674a',
#  'https://medium.com/through-the-datascope/instagrams-blind-spot-fde90b6238f4',
#  'https://medium.com/through-the-datascope/whos-at-the-center-of-the-star-trek-universe-993d6bae045',
#  'https://medium.com/through-the-datascope/why-data-scientists-need-to-ask-why-8bfc7d0f50e9',
#  'https://medium.com/@brookewatson/intersectional-public-health-filling-the-gaps-for-adolescents-487a27c308b2',
#  ...]

# %%
sample = master_articles[:20]

# %%
#check if the article is associated with a publication
def check_pub(soup):
    try:
        soup.find_all('a',{'class':'js-collectionLogoOrName'})
        return 1
    except: return 0

# %%
#get_writer

def get_author(soup):
    try:
        author_url = soup.find('a',{'data-action-source':'post_header_lockup'})
        author_url = author_url['href']
        author_url = re.sub('\?source(.*)','',author_url)
        return author_url
    except: return np.nan

# %%
#get the date and time of the article:
def get_datetime(soup): 
    try: 
        published = soup.find('time')
        return published['datetime']
    except: return np.nan

# %%
#get the reading time for the article

def get_reading_time(soup):
    try:
        reading = soup.find('span',{'class':'readingTime'})
        reading = reading['title']
        #reading = list(filter(str.isdigit, reading))
        #return int(''.join(reading))
        return reading
    except: return np.nan

# %%
#get the tags for the article
def get_tags(soup):
    tag_list = []
    try:
        tags = articlesoup.find('ul',{'class':'tags tags--postTags tags--borderless'})
        tags = tags.find_all('li')
        for tag in tags:
            tag_list.append(tag.text)
        return tag_list
    except: return tag_list

# %%
def get_claps(soup):
    try: 
        claps = articlesoup.find('button',{'data-action':'show-recommends'})
        return claps.text
    except: return 0

def get_claps2(soup):
    try: 
        claps = articlesoup.find('span',{'class':'u-textAlignCenter u-relative u-background js-actionMultirecommendCount u-marginLeft10'})
        if len(claps.text) == 0:
            return 0
        else: return claps.text
    except: return 0

# %%
def get_meta_traits(soup):
    article_traits = {}
    currentURL =  driver.current_url
    article_traits[currentURL] = {}
    article_traits[currentURL] = {'publisher': check_pub(articlesoup)}
    article_traits[currentURL].update({'author': get_author(articlesoup)})
    article_traits[currentURL].update({'datetime': get_datetime(articlesoup)})
    article_traits[currentURL].update({'reading_time': get_reading_time(articlesoup)})
    article_traits[currentURL].update({'claps': get_claps2(articlesoup)})
    article_traits[currentURL].update({'tags': get_tags(articlesoup)})

    return article_traits

# %%
#get all attributes around the article text

def get_text_traits(soup):
    article_text_traits= {}
    #get the number of images and add to dictionary
    article_images = soup.find_all('img',{'class' : 'progressiveMedia-image js-progressiveMedia-image'})
    if article_images:
        #add to dictionary
        article_text_traits['images'] = len(article_images)
    else: article_text_traits['images'] = 0
    
    #get the tota; text block for the article
    article_text = articlesoup.find_all('p')
    total_text = ''
    if article_text:
        for text in article_text:
            total_text+=(text.text)
            
        #get total word count
        article_text_traits['words'] = len(total_text.split())
        
        #get sentence count
        article_text_traits['sentences'] = total_text.count('.')
        
        #get flesch readability
        try:
            s = Textatistic(total_text)
            article_text_traits['flesch'] = s.flesch_score
        except: article_text_traits['flesch'] = np.nan
            
        #get sentiments
        try:
            testimonial = TextBlob(total_text)
            article_text_traits['polarity'] = testimonial.sentiment.polarity
            article_text_traits['subjectivity'] = testimonial.sentiment.subjectivity
            article_text_traits['language'] = testimonial.detect_language()
        except: 
            article_text_traits['polarity'] = np.nan
            article_text_traits['subjectivity'] = np.nan
            article_text_traits['language'] = np.nan
            
    else:
        article_text_traits['words'] = np.nan
        article_text_traits['sentences'] = np.nan
        article_text_traits['flesch'] = np.nan
        article_text_traits['polarity'] = np.nan
        article_text_traits['subjectivity'] = np.nan
        article_text_traits['language'] = np.nan
        
    
    return article_text_traits

# %% [markdown]
# ## Loop through articles, applying all trait functions

# %%
master_article_traits = {}
#if have closed driver
driver = webdriver.Chrome(executable_path="/Users/mayamidzik/tools/chromedriver")
for url in master_articles:
    driver.get(url)
    try:
        articleHTML = driver.execute_script("return document.body.innerHTML")
        articlesoup = BeautifulSoup(articleHTML,"lxml")

        currentURL =  driver.current_url
        article_meta_traits = get_meta_traits(articlesoup)
        article_text_traits = get_text_traits(articlesoup)
        article_meta_traits[currentURL].update(article_text_traits)
        master_article_traits.update(article_meta_traits)
    except TimeoutException:
        pass

with open('jonathonmorgan_articles_claps_redo.pkl', 'wb') as picklefile:
    pickle.dump(master_article_traits, picklefile)

#write to a dataframe
df = pd.DataFrame.from_dict(master_article_traits).T
df.reset_index(level=0, inplace=True)
df['index'] = df
df.rename(columns = {'index':'url'},inplace = True)

df.to_pickle('jonathonmorgan_articles_claps_redo_df.pkl')

# %%
#1415
len(master_article_traits)
# Out:
# 3757

# %%
df.to_pickle('jonathonmorgan_articles_claps_redo_df.2pkl')
